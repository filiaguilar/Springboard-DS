# %%
import pandas as pd

df = pd.read_csv('MetacriticGameReviews.csv', index_col = 0)

# %%
witcher = df[df['title'] == 'The Witcher 3: Wild Hunt']
witcher.head(15)
# Out:
#                         title  platform  metascore metasentiment  \
# 150  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 151  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 152  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 153  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 154  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 155  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 156  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 157  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 158  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 159  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 160  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 161  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# 162  The Witcher 3: Wild Hunt  Xbox One       91.0      positive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20775 entries, 0 to 20774
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  20775 non-null  object
#  1   platform               20775 non-null  object
#  2   metascore              20730 non-null  float64
#  3   metasentiment          20730 non-null  object
#  4   average_userscore      20730 non-null  float64
#  5   average_usersentiment  20730 non-null  object
#  6   developer              20730 non-null  object
#  7   genre                  20745 non-null  object
#  8   number_of_players      17280 non-null  object
#  9   esrb_rating            20280 non-null  object
#  10  release_date           20745 non-null  object
#  11  username               20775 non-null  object
#  12  userscore              20775 non-null  int64
#  13  review                 20773 non-null  object
# ...

# %%
df.number_of_players.value_counts()
# Out:
# No Online Multiplayer    8055
# Up to 4                  1860
# 2                        1575
# Up to 8                  1110
# Up to 10                  660
# Up to 6                   645
# Up to 12                  555
# Up to 16                  435
# Up to 22                  375
# Online Multiplayer        330
# Up to 5                   225
# Up to 18                  195
# Up to 24                  180
# Up to more than 64        180
# Massively Multiplayer     165
# Up to 64                  165
# Up to 3                   150
# Up to 20                  135
# Up to 32                   90
# Up to 40                   75
# Up to 60                   45
# Up to 30                   45
# 1 Player                   30
# Name: number_of_players, dtype: int64

# %%
single_player = df[(df['number_of_players'] == 'No Online Multiplayer') | (df['number_of_players'] == '1 Player')]
single_player.genre.value_counts()
# Out:
# ['Action Adventure', 'General']                                       795
# ['Role-Playing', 'Action RPG']                                        690
# ['Action', 'Platformer', '2D']                                        660
# ['Action Adventure', 'Open-World']                                    645
# ['Action Adventure', 'Survival']                                      315
#                                                                      ...
# ['Fantasy', 'Fantasy', 'Action Adventure', 'Linear']                   15
# ['Action', 'Action Adventure', 'General', 'General', 'Open-World']     15
# ['Modern', 'Action Adventure', 'General']                              15
# ['Strategy', 'Turn-Based', 'General', 'Tactics']                       15
# ['Role-Playing', 'Action RPG', 'Action RPG']                           15
# Name: genre, Length: 141, dtype: int64

# %%
df.genre.value_counts()
# Out:
# ['Role-Playing', 'Action RPG']                                                                                 1395
# ['Action Adventure', 'General']                                                                                1140
# ['Action', 'Platformer', '2D']                                                                                 1020
# ['Action Adventure', 'Open-World']                                                                              945
# ['Action', 'Shooter', 'First-Person', 'Arcade']                                                                 885
#                                                                                                                ...
# ['Action Adventure', 'General', 'Role-Playing', 'Action RPG']                                                    15
# ['Action', 'Action Adventure', 'Shooter', 'Survival', 'First-Person', 'Third-Person', 'Tactical', 'Arcade']      15
# ...
